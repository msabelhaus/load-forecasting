# %%
# Libraries
import pandas as pd
import numpy as np
import math
import datetime as dt
import time
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import scipy.interpolate as interpolate

# %matplotlib inline
plt.style.use("seaborn")

# %%
# Read in data
load_data = pd.read_csv("data/load_3yback_NE.csv")
weather_data = pd.read_csv("data/weather_3yback_NE.csv")

# %% [markdown]
# ## Merge the datasets on average hourly load and weather conditions

# %%
# Quick look at data
load_data.head()
# Out:
#       Load Region Source of Data Local Datetime (Hour Ending) Time Zone  \
# 0  .Z.CONNECTICUT             NE              10/22/2018 1:00       EDT
# 1  .Z.CONNECTICUT             NE              10/22/2018 2:00       EDT
# 2  .Z.CONNECTICUT             NE              10/22/2018 3:00       EDT
# 3  .Z.CONNECTICUT             NE              10/22/2018 4:00       EDT
# 4  .Z.CONNECTICUT             NE              10/22/2018 5:00       EDT
#
#   Load Type  Load MW Load Market Data Type  Record Count  \
# 0      LOAD   2470.0      HOURLY    Actual             1
# 1      LOAD   2397.0      HOURLY    Actual             1
# 2      LOAD   2374.6      HOURLY    Actual             1
# 3      LOAD   2392.0      HOURLY    Actual             1
# 4      LOAD   2486.2      HOURLY    Actual             1
#
#   Local Datetime (Hour Beginning)  Month  Hour (Hour Ending 1-24) Day of Week  \
# 0                 10/22/2018 0:00     10                        1      Monday
# 1                 10/22/2018 1:00     10                        2      Monday
# 2                 10/22/2018 2:00     10                        3      Monday
# 3                 10/22/2018 3:00     10                        4      Monday
# 4                 10/22/2018 4:00     10                        5      Monday
#
#   Holiday (Y/N) Weekday/Weekend On Peak/Off Peak - EAST  Min Load MW  \
# 0             N         Weekday                Off Peak       2470.0
# 1             N         Weekday                Off Peak       2397.0
# 2             N         Weekday                Off Peak       2374.6
# 3             N         Weekday                Off Peak       2392.0
# 4             N         Weekday                Off Peak       2486.2
#
#    Max Load MW
# 0       2470.0
# 1       2397.0
# 2       2374.6
# 3       2392.0
# 4       2486.2

# %%
# Looking at subset of weather reports for Connecticut ISO Zone
weather_data[weather_data['Weather Station Name'] == 'Hartford Brainard Arpt']
# Out:
#          Weather Station Name Local Datetime (Hour Beginning)  \
# 26325  Hartford Brainard Arpt                 10/22/2018 0:00
# 26326  Hartford Brainard Arpt                 10/22/2018 1:00
# 26327  Hartford Brainard Arpt                 10/22/2018 2:00
# 26328  Hartford Brainard Arpt                 10/22/2018 3:00
# 26329  Hartford Brainard Arpt                 10/22/2018 4:00
# ...                       ...                             ...
# 52645  Hartford Brainard Arpt                10/22/2021 16:00
# 52646  Hartford Brainard Arpt                10/22/2021 17:00
# 52647  Hartford Brainard Arpt                10/22/2021 18:00
# 52648  Hartford Brainard Arpt                10/22/2021 19:00
# 52649  Hartford Brainard Arpt                10/22/2021 20:00
#
#        Temperature (Dry Bulb) - Fahrenheit  Relative Humidity Percent  \
# 26325                                 34.0                       75.0
# 26326                                 30.9                       78.0
# 26327                                 28.9                       89.0
# 26328                                 30.0                       88.0
# 26329                                 30.9                       82.0
# ...                                    ...                        ...
# 52645                                 66.2                       56.0
# 52646                                 64.4                       56.0
# 52647                                 62.6                       52.0
# 52648                                 59.0                       59.0
# 52649                                 57.2                       59.0
#
#       Local Datetime (Hour Ending)
# 26325              10/22/2018 1:00
# 26326              10/22/2018 2:00
# 26327              10/22/2018 3:00
# 26328              10/22/2018 4:00
# 26329              10/22/2018 5:00
# ...                            ...
# 52645             10/22/2021 17:00
# 52646             10/22/2021 18:00
# 52647             10/22/2021 19:00
# 52648             10/22/2021 20:00
# 52649             10/22/2021 21:00
#
# [26325 rows x 5 columns]

# %% [markdown]
# Let's include weather station names as variables in our load dataset for merging purposes.
# <br>
# Mappings are:
# <br>
# CONNETICUT - Hartford Brainard Arpt
# <br>
# MAINE - Milinocket Arpt
# <br>
# NEWHAMPSHIRE - St Johnsbury
# <br>
# RHODEISLAND - Newport State Arpt
# <br>
# SEMASS - New Bedford Regional Arpt
# <br>
# VERMONT - Hartness State Springfield Arpt
# <br>
# WCMASS - Westfield Barnes Municipal Arpt
# <br>
# NEMASSBOST - Beverly Municipal Arpt

# %%
# Drop ISOs in load data I don't have weather data for
load_data = load_data[~load_data["Load Region"].isin([".Z.SEMASS",".Z.WCMASS",".Z.MAINE"])]

# %%
# Checking to make sure I have regions for each report
# I will use the variable 'regions' for mapping later
regions = load_data["Load Region"].unique()
regions
# Out:
# array(['.Z.CONNECTICUT', '.Z.NEMASSBOST', '.Z.NEWHAMPSHIRE',
#        '.Z.RHODEISLAND', '.Z.VERMONT'], dtype=object)

# %%
stations = weather_data["Weather Station Name"].unique()

# Rearrange into correct list
idx = [1,0,4,3,2]
stations = stations[idx]

# %% [markdown]
# Creating a function to numerically assign ISO zones to weather regions.

# %%
def f(row):
    if row == regions[0]:
        val = stations[0]
    elif row == regions[1]:
        val = stations[1]
    elif row == regions[2]:
        val = stations[2]
    elif row == regions[3]:
        val = stations[3]
    elif row == regions[4]:
        val = stations[4]
    return val

# %%
# Adding in weather station mappings
load_data["Weather Station Name"] = load_data["Load Region"].apply(f)

# %% [markdown]
# For the purpose of this exercise I will restrict the data to only the Connecticut ISO zone. Note the same procedure can be applied to the other ISO NE regions.

# %%
connecticutLoad = load_data[load_data["Load Region"] == '.Z.CONNECTICUT']
len(connecticutLoad)
# Out:
# 26256

# %%
# Map weather to ISO zone by station name
connecticut = pd.merge(connecticutLoad, weather_data,  how='left', left_on=['Local Datetime (Hour Beginning)','Weather Station Name'], right_on = ['Local Datetime (Hour Beginning)','Weather Station Name'])
len(connecticut)
# Out:
# 26256

# %%
connecticut.head()
# Out:
#       Load Region Source of Data Local Datetime (Hour Ending)_x Time Zone  \
# 0  .Z.CONNECTICUT             NE                10/22/2018 1:00       EDT
# 1  .Z.CONNECTICUT             NE                10/22/2018 2:00       EDT
# 2  .Z.CONNECTICUT             NE                10/22/2018 3:00       EDT
# 3  .Z.CONNECTICUT             NE                10/22/2018 4:00       EDT
# 4  .Z.CONNECTICUT             NE                10/22/2018 5:00       EDT
#
#   Load Type  Load MW Load Market Data Type  Record Count  \
# 0      LOAD   2470.0      HOURLY    Actual             1
# 1      LOAD   2397.0      HOURLY    Actual             1
# 2      LOAD   2374.6      HOURLY    Actual             1
# 3      LOAD   2392.0      HOURLY    Actual             1
# 4      LOAD   2486.2      HOURLY    Actual             1
#
#   Local Datetime (Hour Beginning)  ...  Day of Week  Holiday (Y/N)  \
# 0                 10/22/2018 0:00  ...       Monday              N
# 1                 10/22/2018 1:00  ...       Monday              N
# 2                 10/22/2018 2:00  ...       Monday              N
# 3                 10/22/2018 3:00  ...       Monday              N
# 4                 10/22/2018 4:00  ...       Monday              N
#
#   Weekday/Weekend On Peak/Off Peak - EAST Min Load MW Max Load MW  \
# 0         Weekday                Off Peak      2470.0      2470.0
# 1         Weekday                Off Peak      2397.0      2397.0
# 2         Weekday                Off Peak      2374.6      2374.6
# 3         Weekday                Off Peak      2392.0      2392.0
# 4         Weekday                Off Peak      2486.2      2486.2
#
#      Weather Station Name  Temperature (Dry Bulb) - Fahrenheit  \
# 0  Hartford Brainard Arpt                                 34.0
# 1  Hartford Brainard Arpt                                 30.9
# 2  Hartford Brainard Arpt                                 28.9
# 3  Hartford Brainard Arpt                                 30.0
# 4  Hartford Brainard Arpt                                 30.9
#
#   Relative Humidity Percent  Local Datetime (Hour Ending)_y
# 0                      75.0                 10/22/2018 1:00
# 1                      78.0                 10/22/2018 2:00
# 2                      89.0                 10/22/2018 3:00
# 3                      88.0                 10/22/2018 4:00
# 4                      82.0                 10/22/2018 5:00
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Filter out variables of interest
#
# Now I'll filter out variables of interest. Also adding variable for the date without hour attached.

# %%
# Filter out variables of interest 

# NOTE: Removing min/max load MW b.c. they are the same as the actual load mw in this dataset
cols_to_remove = ['Load Region','Source of Data','Time Zone','Load Type',
                  'Load Market','Data Type','Record Count','Local Datetime (Hour Ending)_x',
                  'Local Datetime (Hour Ending)_y','Min Load MW','Max Load MW']

connecticut = connecticut.drop(cols_to_remove, axis=1)

connecticut.head()
# Out:
#    Load MW Local Datetime (Hour Beginning)  Month  Hour (Hour Ending 1-24)  \
# 0   2470.0                 10/22/2018 0:00     10                        1
# 1   2397.0                 10/22/2018 1:00     10                        2
# 2   2374.6                 10/22/2018 2:00     10                        3
# 3   2392.0                 10/22/2018 3:00     10                        4
# 4   2486.2                 10/22/2018 4:00     10                        5
#
#   Day of Week Holiday (Y/N) Weekday/Weekend On Peak/Off Peak - EAST  \
# 0      Monday             N         Weekday                Off Peak
# 1      Monday             N         Weekday                Off Peak
# 2      Monday             N         Weekday                Off Peak
# 3      Monday             N         Weekday                Off Peak
# 4      Monday             N         Weekday                Off Peak
#
#      Weather Station Name  Temperature (Dry Bulb) - Fahrenheit  \
# 0  Hartford Brainard Arpt                                 34.0
# 1  Hartford Brainard Arpt                                 30.9
# 2  Hartford Brainard Arpt                                 28.9
# 3  Hartford Brainard Arpt                                 30.0
# 4  Hartford Brainard Arpt                                 30.9
#
#    Relative Humidity Percent
# 0                       75.0
# 1                       78.0
# 2                       89.0
# 3                       88.0
# 4                       82.0

# %%
# Rename columns // makes things easier
col_names = ['LoadMW','LocalDt','M','HourE','DOW','Holiday','DayType','Peak',
             'Station','TempF','Humidity']
connecticut.columns = col_names

# %%
# Create new variable for date without hour attached
connecticut["Date"] = connecticut["LocalDt"].apply(
    lambda x: dt.datetime.strptime(x, "%m/%d/%Y %H:%M").strftime('%Y-%m-%d')
)
connecticut["DateTimeObj"] = connecticut["LocalDt"].apply(
    lambda x: dt.datetime.strptime(x, "%m/%d/%Y %H:%M")
)

# Creating variable for year/day. These are helpful for isolating certain times
connecticut["Y"] = connecticut["LocalDt"].apply(
    lambda x: dt.datetime.strptime(x, "%m/%d/%Y %H:%M").strftime('%Y')
)
connecticut["D"] = connecticut["LocalDt"].apply(
    lambda x: dt.datetime.strptime(x, "%m/%d/%Y %H:%M").strftime('%d')
)

# %% [markdown]
# ## Create additional variables

# %% [markdown]
# First generate a variable for the next hour's load. Originally I had also created variables for lagged hourly load, but these proved to be not necessary for the stacked LSTM design used in modeling.
#
# Note for future work: this can easily be extended to t+2, t+3, etc., i.e. can be used to forecast a load profile.

# %%
# Ensuring that samples are sorted by time correctly
connecticut = connecticut.sort_values(by = "DateTimeObj")

# Load t+1
LoadMW_Plus1 = connecticut["LoadMW"].shift(periods=-1)
LoadMW_Plus1.name = 'LoadMW_Plus1'

connecticut = pd.concat([connecticut, LoadMW_Plus1], axis=1)

# %% [markdown]
# Next I create a one-hot encoding of the $Holiday$ and $Peak$ variables.

# %%
# Make dummy for peak/nonpeak
peakDummy = pd.get_dummies(connecticut['Peak'])
connecticut['OnPeak'] = peakDummy['On Peak']

# Make dummy for holiday
holidayDummy = pd.get_dummies(connecticut['Holiday'])
connecticut['Holiday'] = holidayDummy['Y']

# %% [markdown]
# My professor recommended that I attempt to include cyclical feature information such as hourly, monthly, or seasonal attributes.
#
# I will create:
# - cosine/sine representations of the hour of day (using $HourE$) and month in the year (using $M$)
# - a one-hot encoding of season

# %%
# Create cosine/sine representation of hour of day

# Normalize HourE values to match with the 0-2π cycle
connecticut["HourE_norm"] = 2 * math.pi * connecticut["HourE"] / connecticut["HourE"].max()

connecticut["cos_HourE"] = np.cos(connecticut["HourE_norm"])
connecticut["sin_HourE"] = np.sin(connecticut["HourE_norm"])

# %%
# Create cosine/sine representation of month

# Normalize M values to match with the 0-2π cycle
connecticut["M_norm"] = 2 * math.pi * connecticut["M"] / connecticut["M"].max()

connecticut["cos_M"] = np.cos(connecticut["M_norm"])
connecticut["sin_M"] = np.sin(connecticut["M_norm"])

# %%
# Create cosine/sine representation of DOW

# First encode DOW numerically
connecticut["DOW"] = connecticut["DOW"].apply(
    lambda x: time.strptime(x, "%A").tm_wday
)

# Normalize DOW values to match with the 0-2π cycle
connecticut["DOW_norm"] = 2 * math.pi * connecticut["DOW"] / connecticut["DOW"].max()

connecticut["cos_DOW"] = np.cos(connecticut["DOW_norm"])
connecticut["sin_DOW"] = np.sin(connecticut["DOW_norm"])

# %%
# Create one-hot encoding of season

# First create season variable
def f(month):
    if month in [12,1,2]:
        return "Winter"
    elif month in [3,4,5]:
        return "Spring"
    elif month in [6,7,8]:
        return "Summer"
    elif month in [9,10,11]:
        return "Fall"

# Adding in season variable
connecticut["Season"] = connecticut["M"].apply(f)

# Make dummies for season and drop 
connecticut = connecticut.join(pd.get_dummies(connecticut['Season']))
connecticut = connecticut.drop("Season", axis = 1)

# %%
# Getting final dataframe visual
#df = connecticut[['LocalDt','LoadMW','LoadMW_Plus1','TempF','Humidity','Holiday','Spring','Summer','Winter','Fall','cos_HourE','sin_HourE','cos_DOW','sin_DOW','OnPeak']]
#df.sample(10)

# %%
# Final filtering of features
connecticut = connecticut[['LocalDt','Date','DateTimeObj','D','M','Y','LoadMW','LoadMW_Plus1','TempF','Humidity','Holiday','Spring','Summer','Winter','Fall','cos_HourE','sin_HourE','cos_DOW','sin_DOW','OnPeak']]
connecticut.head()
# Out:
#            LocalDt        Date         DateTimeObj   D   M     Y  LoadMW  \
# 0  10/22/2018 0:00  2018-10-22 2018-10-22 00:00:00  22  10  2018  2470.0
# 1  10/22/2018 1:00  2018-10-22 2018-10-22 01:00:00  22  10  2018  2397.0
# 2  10/22/2018 2:00  2018-10-22 2018-10-22 02:00:00  22  10  2018  2374.6
# 3  10/22/2018 3:00  2018-10-22 2018-10-22 03:00:00  22  10  2018  2392.0
# 4  10/22/2018 4:00  2018-10-22 2018-10-22 04:00:00  22  10  2018  2486.2
#
#    LoadMW_Plus1  TempF  Humidity  Holiday  Spring  Summer  Winter  Fall  \
# 0        2397.0   34.0      75.0        0       0       0       0     1
# 1        2374.6   30.9      78.0        0       0       0       0     1
# 2        2392.0   28.9      89.0        0       0       0       0     1
# 3        2486.2   30.0      88.0        0       0       0       0     1
# 4        2751.4   30.9      82.0        0       0       0       0     1
#
#    cos_HourE  sin_HourE  cos_DOW  sin_DOW  OnPeak
# 0   0.965926   0.258819      1.0      0.0       0
# 1   0.866025   0.500000      1.0      0.0       0
# 2   0.707107   0.707107      1.0      0.0       0
# 3   0.500000   0.866025      1.0      0.0       0
# 4   0.258819   0.965926      1.0      0.0       0

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Checking for missing values and any other oddities.

# %%
null_data = connecticut[connecticut.isnull().any(axis=1)]
null_data
# Out:
#                 LocalDt        Date         DateTimeObj   D   M     Y  \
# 15664    8/4/2020 16:00  2020-08-04 2020-08-04 16:00:00  04   8  2020
# 15665    8/4/2020 17:00  2020-08-04 2020-08-04 17:00:00  04   8  2020
# 15666    8/4/2020 18:00  2020-08-04 2020-08-04 18:00:00  04   8  2020
# 15667    8/4/2020 19:00  2020-08-04 2020-08-04 19:00:00  04   8  2020
# 15668    8/4/2020 20:00  2020-08-04 2020-08-04 20:00:00  04   8  2020
# 15669    8/4/2020 21:00  2020-08-04 2020-08-04 21:00:00  04   8  2020
# 15670    8/4/2020 22:00  2020-08-04 2020-08-04 22:00:00  04   8  2020
# 15671    8/4/2020 23:00  2020-08-04 2020-08-04 23:00:00  04   8  2020
# 15672     8/5/2020 0:00  2020-08-05 2020-08-05 00:00:00  05   8  2020
# 15673     8/5/2020 1:00  2020-08-05 2020-08-05 01:00:00  05   8  2020
# 15674     8/5/2020 2:00  2020-08-05 2020-08-05 02:00:00  05   8  2020
# 15675     8/5/2020 3:00  2020-08-05 2020-08-05 03:00:00  05   8  2020
# 15676     8/5/2020 4:00  2020-08-05 2020-08-05 04:00:00  05   8  2020
# 15677     8/5/2020 5:00  2020-08-05 2020-08-05 05:00:00  05   8  2020
# 15678     8/5/2020 6:00  2020-08-05 2020-08-05 06:00:00  05   8  2020
# 15679     8/5/2020 7:00  2020-08-05 2020-08-05 07:00:00  05   8  2020
# 15680     8/5/2020 8:00  2020-08-05 2020-08-05 08:00:00  05   8  2020
# 15681     8/5/2020 9:00  2020-08-05 2020-08-05 09:00:00  05   8  2020
# 15682    8/5/2020 10:00  2020-08-05 2020-08-05 10:00:00  05   8  2020
# 15683    8/5/2020 11:00  2020-08-05 2020-08-05 11:00:00  05   8  2020
# 15684    8/5/2020 12:00  2020-08-05 2020-08-05 12:00:00  05   8  2020
# 15685    8/5/2020 13:00  2020-08-05 2020-08-05 13:00:00  05   8  2020
# 15686    8/5/2020 14:00  2020-08-05 2020-08-05 14:00:00  05   8  2020
# 15687    8/5/2020 15:00  2020-08-05 2020-08-05 15:00:00  05   8  2020
# 15688    8/5/2020 16:00  2020-08-05 2020-08-05 16:00:00  05   8  2020
# 15689    8/5/2020 17:00  2020-08-05 2020-08-05 17:00:00  05   8  2020
# 15690    8/5/2020 18:00  2020-08-05 2020-08-05 18:00:00  05   8  2020
# 15691    8/5/2020 19:00  2020-08-05 2020-08-05 19:00:00  05   8  2020
# 15692    8/5/2020 20:00  2020-08-05 2020-08-05 20:00:00  05   8  2020
# 15693    8/5/2020 21:00  2020-08-05 2020-08-05 21:00:00  05   8  2020
# 15694    8/5/2020 22:00  2020-08-05 2020-08-05 22:00:00  05   8  2020
# 15695    8/5/2020 23:00  2020-08-05 2020-08-05 23:00:00  05   8  2020
# 15696     8/6/2020 0:00  2020-08-06 2020-08-06 00:00:00  06   8  2020
# 15697     8/6/2020 1:00  2020-08-06 2020-08-06 01:00:00  06   8  2020
# 15698     8/6/2020 2:00  2020-08-06 2020-08-06 02:00:00  06   8  2020
# 15699     8/6/2020 3:00  2020-08-06 2020-08-06 03:00:00  06   8  2020
# 15700     8/6/2020 4:00  2020-08-06 2020-08-06 04:00:00  06   8  2020
# 15701     8/6/2020 5:00  2020-08-06 2020-08-06 05:00:00  06   8  2020
# 15702     8/6/2020 6:00  2020-08-06 2020-08-06 06:00:00  06   8  2020
# 15703     8/6/2020 7:00  2020-08-06 2020-08-06 07:00:00  06   8  2020
# 15704     8/6/2020 8:00  2020-08-06 2020-08-06 08:00:00  06   8  2020
# 15705     8/6/2020 9:00  2020-08-06 2020-08-06 09:00:00  06   8  2020
# 15706    8/6/2020 10:00  2020-08-06 2020-08-06 10:00:00  06   8  2020
# 15707    8/6/2020 11:00  2020-08-06 2020-08-06 11:00:00  06   8  2020
# 15708    8/6/2020 12:00  2020-08-06 2020-08-06 12:00:00  06   8  2020
# 26255  10/19/2021 23:00  2021-10-19 2021-10-19 23:00:00  19  10  2021
#
#         LoadMW  LoadMW_Plus1  TempF  Humidity  Holiday  Spring  Summer  \
# 15664  2886.90        2709.9    NaN       NaN        0       0       1
# 15665  2709.90        2588.3    NaN       NaN        0       0       1
# 15666  2588.30        2536.4    NaN       NaN        0       0       1
# 15667  2536.40        2524.4    NaN       NaN        0       0       1
# 15668  2524.40        2469.9    NaN       NaN        0       0       1
# 15669  2469.90        2299.5    NaN       NaN        0       0       1
# 15670  2299.50        2140.5    NaN       NaN        0       0       1
# 15671  2140.50        2016.4    NaN       NaN        0       0       1
# 15672  2016.40        1942.6    NaN       NaN        0       0       1
# 15673  1942.60        1889.1    NaN       NaN        0       0       1
# 15674  1889.10        1863.7    NaN       NaN        0       0       1
# 15675  1863.70        1880.6    NaN       NaN        0       0       1
# 15676  1880.60        1962.8    NaN       NaN        0       0       1
# 15677  1962.80        2122.6    NaN       NaN        0       0       1
# 15678  2122.60        2343.8    NaN       NaN        0       0       1
# 15679  2343.80        2562.5    NaN       NaN        0       0       1
# 15680  2562.50        2744.7    NaN       NaN        0       0       1
# 15681  2744.70        2955.0    NaN       NaN        0       0       1
# 15682  2955.00        3133.4    NaN       NaN        0       0       1
# 15683  3133.40        3268.3    NaN       NaN        0       0       1
# 15684  3268.30        3362.9    NaN       NaN        0       0       1
# 15685  3362.90        3446.2    NaN       NaN        0       0       1
# 15686  3446.20        3509.2    NaN       NaN        0       0       1
# 15687  3509.20        3551.9    NaN       NaN        0       0       1
# 15688  3551.90        3570.3    NaN       NaN        0       0       1
# 15689  3570.30        3498.5    NaN       NaN        0       0       1
# 15690  3498.50        3356.8    NaN       NaN        0       0       1
# 15691  3356.80        3250.3    NaN       NaN        0       0       1
# 15692  3250.30        3070.8    NaN       NaN        0       0       1
# 15693  3070.80        2793.0    NaN       NaN        0       0       1
# 15694  2793.00        2532.3    NaN       NaN        0       0       1
# 15695  2532.30        2328.8    NaN       NaN        0       0       1
# 15696  2328.80        2196.9    NaN       NaN        0       0       1
# 15697  2196.90        2088.9    NaN       NaN        0       0       1
# 15698  2088.90        2016.5    NaN       NaN        0       0       1
# 15699  2016.50        2003.3    NaN       NaN        0       0       1
# 15700  2003.30        2077.5    NaN       NaN        0       0       1
# 15701  2077.50        2204.4    NaN       NaN        0       0       1
# 15702  2204.40        2399.2    NaN       NaN        0       0       1
# 15703  2399.20        2598.7    NaN       NaN        0       0       1
# 15704  2598.70        2747.6    NaN       NaN        0       0       1
# 15705  2747.60        2891.1    NaN       NaN        0       0       1
# 15706  2891.10        3000.8    NaN       NaN        0       0       1
# 15707  3000.80        3083.3    NaN       NaN        0       0       1
# 15708  3083.30        3163.7    NaN       NaN        0       0       1
# 26255  2411.18           NaN   53.6      58.0        0       0       0
#
#        Winter  Fall     cos_HourE     sin_HourE  cos_DOW       sin_DOW  OnPeak
# 15664       0     0 -2.588190e-01 -9.659258e-01      0.5  8.660254e-01       1
# 15665       0     0 -1.836970e-16 -1.000000e+00      0.5  8.660254e-01       1
# 15666       0     0  2.588190e-01 -9.659258e-01      0.5  8.660254e-01       1
# 15667       0     0  5.000000e-01 -8.660254e-01      0.5  8.660254e-01       1
# 15668       0     0  7.071068e-01 -7.071068e-01      0.5  8.660254e-01       1
# 15669       0     0  8.660254e-01 -5.000000e-01      0.5  8.660254e-01       1
# 15670       0     0  9.659258e-01 -2.588190e-01      0.5  8.660254e-01       1
# 15671       0     0  1.000000e+00 -2.449294e-16      0.5  8.660254e-01       0
# 15672       0     0  9.659258e-01  2.588190e-01     -0.5  8.660254e-01       0
# 15673       0     0  8.660254e-01  5.000000e-01     -0.5  8.660254e-01       0
# 15674       0     0  7.071068e-01  7.071068e-01     -0.5  8.660254e-01       0
# 15675       0     0  5.000000e-01  8.660254e-01     -0.5  8.660254e-01       0
# 15676       0     0  2.588190e-01  9.659258e-01     -0.5  8.660254e-01       0
# 15677       0     0  6.123234e-17  1.000000e+00     -0.5  8.660254e-01       0
# 15678       0     0 -2.588190e-01  9.659258e-01     -0.5  8.660254e-01       0
# 15679       0     0 -5.000000e-01  8.660254e-01     -0.5  8.660254e-01       1
# 15680       0     0 -7.071068e-01  7.071068e-01     -0.5  8.660254e-01       1
# 15681       0     0 -8.660254e-01  5.000000e-01     -0.5  8.660254e-01       1
# 15682       0     0 -9.659258e-01  2.588190e-01     -0.5  8.660254e-01       1
# 15683       0     0 -1.000000e+00  1.224647e-16     -0.5  8.660254e-01       1
# 15684       0     0 -9.659258e-01 -2.588190e-01     -0.5  8.660254e-01       1
# 15685       0     0 -8.660254e-01 -5.000000e-01     -0.5  8.660254e-01       1
# 15686       0     0 -7.071068e-01 -7.071068e-01     -0.5  8.660254e-01       1
# 15687       0     0 -5.000000e-01 -8.660254e-01     -0.5  8.660254e-01       1
# 15688       0     0 -2.588190e-01 -9.659258e-01     -0.5  8.660254e-01       1
# 15689       0     0 -1.836970e-16 -1.000000e+00     -0.5  8.660254e-01       1
# 15690       0     0  2.588190e-01 -9.659258e-01     -0.5  8.660254e-01       1
# 15691       0     0  5.000000e-01 -8.660254e-01     -0.5  8.660254e-01       1
# 15692       0     0  7.071068e-01 -7.071068e-01     -0.5  8.660254e-01       1
# 15693       0     0  8.660254e-01 -5.000000e-01     -0.5  8.660254e-01       1
# 15694       0     0  9.659258e-01 -2.588190e-01     -0.5  8.660254e-01       1
# 15695       0     0  1.000000e+00 -2.449294e-16     -0.5  8.660254e-01       0
# 15696       0     0  9.659258e-01  2.588190e-01     -1.0  1.224647e-16       0
# 15697       0     0  8.660254e-01  5.000000e-01     -1.0  1.224647e-16       0
# 15698       0     0  7.071068e-01  7.071068e-01     -1.0  1.224647e-16       0
# 15699       0     0  5.000000e-01  8.660254e-01     -1.0  1.224647e-16       0
# 15700       0     0  2.588190e-01  9.659258e-01     -1.0  1.224647e-16       0
# 15701       0     0  6.123234e-17  1.000000e+00     -1.0  1.224647e-16       0
# 15702       0     0 -2.588190e-01  9.659258e-01     -1.0  1.224647e-16       0
# 15703       0     0 -5.000000e-01  8.660254e-01     -1.0  1.224647e-16       1
# 15704       0     0 -7.071068e-01  7.071068e-01     -1.0  1.224647e-16       1
# 15705       0     0 -8.660254e-01  5.000000e-01     -1.0  1.224647e-16       1
# 15706       0     0 -9.659258e-01  2.588190e-01     -1.0  1.224647e-16       1
# 15707       0     0 -1.000000e+00  1.224647e-16     -1.0  1.224647e-16       1
# 15708       0     0 -9.659258e-01 -2.588190e-01     -1.0  1.224647e-16       1
# 26255       0     1  1.000000e+00 -2.449294e-16      0.5  8.660254e-01       0

# %% [markdown]
# I am missing temperature/humidity data from 8/4/20 17:00 to 8/6/20 13:00.
#
# I can handle this by either:
# - Deleting rows
# - Imputing the data
#
# I decided to look at the graph of hourly data from:
# - August of the last year compared to 2020
# - July and August of 2020
#
# This is to gauge how similar the various series are. My thought process is that if I see a similar trend in either the year before or in the surrounding months, it may be valid to interpolate those missing days in August 2020.

# %%
# Aug 2019
df1 = connecticut[(connecticut['Y']=='2019') & (connecticut['M']==8)]

# Aug 2020
df2 = connecticut[(connecticut['Y']=='2020') & (connecticut['M']==8)]

fig, (ax1, ax2) = plt.subplots(2)
fig.suptitle('Average Hourly Temperature (Aug 2019 and 2020)')
ax1.plot(df1.DateTimeObj, df1.TempF)
ax2.plot(df2.DateTimeObj, df2.TempF)

# %%
# July
df3 = connecticut[(connecticut['Y']=='2020') & (connecticut['M']==7)]

# Sep
df4 = connecticut[(connecticut['Y']=='2020') & (connecticut['M']==9)]

fig, (ax1, ax2) = plt.subplots(2)
fig.suptitle('Average Hourly Temperature (July 2020 and Sep 2020)')
ax1.plot(df3.DateTimeObj, df3.TempF)
ax2.plot(df4.DateTimeObj, df4.TempF)

# %% [markdown]
# The lack of a consistent trend in the same month of the past year, and surrounding months of the current year, has me wary of interpolating these values. It seems safest to drop any samples without a value for average temperature.

# %%
# Drop these samples
connecticut = connecticut.dropna()

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# Creating some charts to get a better feel of the data.

# %%
# Distribution of load 
plt.xlabel("Load")
plt.ylabel("Frequency")
num_bins = 10
plt.suptitle('Distribution of Load')
n, bins, patches = plt.hist(connecticut['LoadMW'], num_bins, facecolor='blue', alpha=0.5)
plt.show()

# %%
# Distribution of temperature
plt.xlabel("Temperature")
plt.ylabel("Frequency")
num_bins = 10
plt.suptitle('Distribution of Average Hourly Temperature')
n, bins, patches = plt.hist(connecticut['TempF'], num_bins, facecolor='red', alpha=0.5)
plt.show()

# %%
# Showing seasonality effect

# Aug 2020
aug20 = connecticut[(connecticut['Y']=='2020') & (connecticut['M']==10)]

fig, axs = plt.subplots()

locator = matplotlib.dates.AutoDateLocator(minticks=7, maxticks=15)
formatter = matplotlib.dates.ConciseDateFormatter(locator)
axs.xaxis.set_major_locator(locator)
axs.xaxis.set_major_formatter(formatter)

axs.plot(aug20["DateTimeObj"], aug20["LoadMW"], color='#009E73')

axs.set_title('Hourly Load for Connecticut ISO Zone (October 2020)', fontdict = {'fontsize' : 18})
axs.set_xlabel("Day", fontdict = {'fontsize' : 14})
axs.set_ylabel("Load (MW)", fontdict = {'fontsize' : 14})

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.show()
#plt.savefig('figures/oct_2020_ts.eps', format='eps')

# %%
# Showing nonlinearity of features with target

# Randomly choosing November 2020
df3 = connecticut[(connecticut['Y']=='2020')]
df4 = connecticut[(connecticut['Y']=='2020')]

fig, (ax1, ax2) = plt.subplots(2)
fig.subplots_adjust(wspace=0.4, hspace=0.4)

ax1.scatter(df3.TempF, df3.LoadMW_Plus1, color='#0072B2')
ax1.set_xlabel("Average Hourly Temperature", fontdict = {'fontsize' : 14})
ax1.set_ylabel("Load (MW)", fontdict = {'fontsize' : 14})

ax2.scatter(df4.Humidity, df4.LoadMW_Plus1, color='#CC79A7')
ax2.set_xlabel("Average Hourly Humidity", fontdict = {'fontsize' : 14})
ax2.set_ylabel("Load (MW)", fontdict = {'fontsize' : 14})

plt.show()
#plt.savefig('figures/temp_humid_scatter.eps', format='eps')

# %%
# Showing periods of rapid fluctuation

# Aug 2020
#df2 = connecticut[(connecticut['Y']=='2019') & (connecticut['M']==10) & (connecticut['D'].isin(['10','11','12']))]
df2 = connecticut[(connecticut['Y']=='2019') & (connecticut['M']==10) & (connecticut['D'].isin(['10']))]
#df2 = connecticut[(connecticut['Y']=='2020') & (connecticut['M']==6) & (connecticut['D'].isin(['30']))]

fig, axs = plt.subplots()

locator = matplotlib.dates.AutoDateLocator(minticks=7, maxticks=10)
formatter = matplotlib.dates.ConciseDateFormatter(locator)
axs.xaxis.set_major_locator(locator)
axs.xaxis.set_major_formatter(formatter)

axs.plot(df2["DateTimeObj"], df2["LoadMW"])

axs.set_title('Hourly Load for Connecticut ISO Zone (October 10, 2019)', fontdict = {'fontsize' : 18})
axs.set_xlabel("Hour", fontdict = {'fontsize' : 14})
axs.set_ylabel("Load (MW)", fontdict = {'fontsize' : 14})

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.show()
#plt.savefig('figures/oct10_19_ts.eps', format='eps')

# %%
# Remove duplicate values
connecticut = connecticut.drop_duplicates('LocalDt',keep='last')

# %% [markdown]
# Save this CSV and do model building in a separate notebook.

# %%
# Writing CSV
connecticut.to_csv('data/connecticutData.csv', index=False)
